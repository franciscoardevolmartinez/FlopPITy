# %%
from floppity import Retrieval, helpers
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', size=16)
import torch
from corner import corner
import cloudpickle as pickle
from tqdm import trange
from floppity.simulators import read_ARCiS_input, ARCiS

# %% [markdown]
# #### Set-up retrieval

# %% [markdown]
# Let's first define the ARCiS input file we will be using, and read the
# observations and parameters to be fit from it. We will also pass the input file and the output directory to the ARCiS simulator (a python wrapper that calls your ARCiS installation).

# %%
arcis_input='/Users/floppityflappity/Work/WISE1828/input_j1828_chem.dat'
pars, obs_list = read_ARCiS_input(arcis_input)

ARCiS_kwargs= dict(
    input_file = arcis_input,
    output_dir = '/Users/floppityflappity/Work/WISE1828/test_K',
)

# %% [markdown]
# Let's now define the training and flow hyperparameters.

# %%
training_kwargs= dict(
    stop_after_epochs = 20,
    num_atoms = 10,
    learning_rate=1e-3,
    force_first_round_loss=True,
    use_combined_loss=True
)

flow_kwargs=dict(
    flow='nsf',
    bins=4,
    transforms=8,
    blocks=2,
    hidden=32,
    dropout=0.01,
    # max_num_epochs=500,
)

# %% [markdown]
# Now let's create our retrieval object and load the observations and priors into it.

# %%
R = Retrieval(ARCiS, do_pca=True)
R.parameters=pars
R.get_obs(obs_list)

# %% [markdown]
# Additional parameters can be added as shown below.
# The post_process tag means that they're not passed onto the simulator but the spectra are modified a posteriori using one of the functions in postprocessing.py

# %%
# R.add_parameter('RV', -40,-30, post_process=True)
# R.add_parameter('vrot', 50,70, post_process=True)

# %% [markdown]
# #### Run retrieval

# %%
R.run(flow_kwargs=flow_kwargs, training_kwargs=training_kwargs, simulator_kwargs=ARCiS_kwargs,
      resume=False, n_threads=8,  n_rounds=5, n_samples=512, n_pca=100, save_data=True, 
      # reuse_prior='/Users/floppityflappity/Work/WISE1828/test_pca_10/data_0.pkl',
      output_dir=ARCiS_kwargs['output_dir']
      )
# Out:
# Starting training...
# Round 1
# Generating training examples.
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_7_6.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_6_6.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 1124.70it/s]
# 100%|██████████| 64/64 [00:00<00:00, 818.52it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_5_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1110.05it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_2_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1031.06it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_0_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1179.97it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_4_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1132.44it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_1_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1109.32it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_3_6.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1164.19it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
#  Neural network successfully converged after 53 epochs.
#         -------------------------
#         ||||| ROUND 1 STATS |||||:
#         -------------------------
#         Epochs trained: 53
#         Best validation performance: 16.3184
#         -------------------------
#
# Round 2
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_3_7.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 865.32it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_6_7.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_0_7.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_1_7.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 738.81it/s]
# 100%|██████████| 64/64 [00:00<00:00, 715.73it/s]
# 100%|██████████| 64/64 [00:00<00:00, 937.63it/s]
# Removing files...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_7_7.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1013.35it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_4_7.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1078.29it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_2_7.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1094.37it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_5_7.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 814.26it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 46 epochs.
#         -------------------------
#         ||||| ROUND 2 STATS |||||:
#         -------------------------
#         Epochs trained: 46
#         Best validation performance: 8.0856
#         -------------------------
#
# Round 3
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_4_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 830.18it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_6_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 891.61it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_2_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 895.45it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_0_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1138.06it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_3_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 828.94it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_5_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1085.08it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_7_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1128.29it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_1_8.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1151.48it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 29 epochs.
#         -------------------------
#         ||||| ROUND 3 STATS |||||:
#         -------------------------
#         Epochs trained: 29
#         Best validation performance: 1.6299
#         -------------------------
#
# Round 4
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_4_9.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_1_9.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_7_9.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 995.60it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_6_9.log
# Reading ARCiS output...
# Removing files...
# Removing files...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 584.44it/s]
# 100%|██████████| 64/64 [00:00<00:00, 756.81it/s]
# 100%|██████████| 64/64 [00:00<00:00, 961.28it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_3_9.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1056.91it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_2_9.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1052.29it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_0_9.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 902.84it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_5_9.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1009.66it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 37 epochs.
#         -------------------------
#         ||||| ROUND 4 STATS |||||:
#         -------------------------
#         Epochs trained: 37
#         Best validation performance: -1.8340
#         -------------------------
#
# Round 5
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_0_10.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1001.46it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_4_10.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1068.66it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_2_10.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 843.03it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_1_10.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_3_10.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 1059.79it/s]
# 100%|██████████| 64/64 [00:00<00:00, 707.28it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_6_10.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 1009.25it/s]
# 100%|██████████| 64/64 [00:00<00:00, 1085.26it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_7_10.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_K/arcis_run_5_10.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1114.16it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 31 epochs.
#         -------------------------
#         ||||| ROUND 5 STATS |||||:
#         -------------------------
#         Epochs trained: 31
#         Best validation performance: -4.6533
#         -------------------------

# %% [markdown]
# #### Plot loss

# %%
# %matplotlib inline
plt.plot(R.inference._summary['best_validation_loss'], marker='o')
plt.xlabel('Round')
plt.ylabel('Validation Loss')
plt.show()

# %% [markdown]
# #### Plot posterior

# %% [markdown]
# This is just to get all the parameter names and priors for the figure labels

# %%
full = []
for key in R.parameters:
    ranges_m = R.parameters[key]['min']
    ranges_p = R.parameters[key]['max']
    full.append((ranges_m, ranges_p))

# %%
CORNER_KWARGS=dict(
    smooth=0.6,
    plot_density=True,
    hist_bin_factor=1,
    plot_contours=True,
    show_titles=True,
    
    range=full,
)
fig=R.plot_corner(-1, color='mediumpurple',**CORNER_KWARGS)

# fig1=R.plot_corner(-2, fig=fig, color='orchid', **CORNER_KWARGS)
# fig2=R.plot_corner(-3, fig=fig, color='pink', **CORNER_KWARGS)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# ## Posterior diagnostics

# %% [markdown]
# ### Posterior predictive check

# %%
x_tensor = R.x_transformer.transform(R.pca.transform(R.noisy_x))

# %%
plt.plot(R.default_obs_norm[0],zorder=1)
for i in range(512):
    plt.plot(x_tensor[i], color='lightgray', alpha=0.05)

# %%
# %matplotlib inline
xs = R.post_x
# Xs=np.concatenate(list(xs.values()), axis=1)

plt.figure(figsize=(40,10))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='r', lw=1, zorder=10)
for i in trange(len(xs['obs1'])):
    for key in R.obs.keys():
        plt.plot(R.obs[key][:,0], xs[key][i], c='b', alpha=0.01, zorder=1)
plt.xlim(0.5,2)
plt.ylim(-1e-5,8e-5)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.show()
# Out:
# 100%|██████████| 512/512 [00:00<00:00, 1596.32it/s]

# %% [markdown]
# ### Check best fitting model from the training set

# %%
bf_idx, bf_chi=helpers.find_best_fit(R.obs, xs)

# %%
plt.figure(figsize=(24,8))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='k', lw=1, zorder=0)
    plt.plot(R.obs[key][:,0], xs[key][bf_idx], c='r', alpha=1, zorder=1)
# plt.xlim(0.9,2)
# plt.ylim(-1e-6,2e-5)
