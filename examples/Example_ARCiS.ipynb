# %%
from floppity import Retrieval, helpers
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', size=16)
import torch
from corner import corner
import cloudpickle as pickle
from tqdm import trange
from floppity.simulators import read_ARCiS_input, ARCiS

# %% [markdown]
# #### Set-up retrieval

# %%
arcis_input='/Users/floppityflappity/Work/WISE1828/input_j1828_free.dat'
pars, obs_list = read_ARCiS_input(arcis_input)

ARCiS_kwargs= dict(
    input_file = arcis_input,
    output_dir = '/Users/floppityflappity/Work/WISE1828/test_codex_version_3',
)

training_kwargs= dict(
    stop_after_epochs = 10,
    num_atoms = 10,
    learning_rate=5e-4
)

flow_kwargs=dict(
    flow='maf',
    # bins=4,
    transforms=20,
    blocks=2,
    hidden=32,
    dropout=0.1
)

R = Retrieval(ARCiS, 'emis')
R.parameters=pars

# R.add_parameter('RV', -40,-30, post_process=True)
# R.add_parameter('vrot', 50,70, post_process=True)

R.get_obs(obs_list)

# %% [markdown]
# #### Run retrieval

# %%
R.run(flow_kwargs=flow_kwargs, resume= True, save_data=True, output_dir=ARCiS_kwargs['output_dir'],alpha=0.1, n_threads=8, training_kwargs=training_kwargs, simulator_kwargs=ARCiS_kwargs, n_rounds=5, n_samples=2048)
# Out:
# Starting training...
# Round 1
# Generating training examples.
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_2_1.log
# Reading ARCiS output...
#  67%|██████▋   | 171/256 [00:00<00:00, 866.44it/s]
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 639.22it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_5_1.log
# Reading ARCiS output...
#  78%|███████▊  | 200/256 [00:00<00:00, 1014.58it/s]
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 924.17it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_3_1.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 790.31it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_1_1.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 740.49it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_6_1.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_7_1.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1029.37it/s]
# 100%|██████████| 256/256 [00:00<00:00, 1006.33it/s]
# Removing files...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_0_1.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1139.66it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_4_1.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1138.20it/s]
# Removing files...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
#  Neural network successfully converged after 154 epochs.
#         -------------------------
#         ||||| ROUND 1 STATS |||||:
#         -------------------------
#         Epochs trained: 154
#         Best validation performance: -7.1306
#         -------------------------
#
# Round 2
# Generating training examples.
# Drawing 1844 posterior samples:   0%|          | 0/1844 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_0_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1207.63it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_3_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1192.03it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_7_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1123.62it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_1_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1222.52it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_5_2.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_2_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1325.63it/s]
# Removing files...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1259.89it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_6_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1447.53it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_4_2.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1311.07it/s]
# Removing files...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/sbi/inference/trainers/npe/npe_base.py:187: UserWarning: The proposal you passed is neither the prior nor a `NeuralPosterior` object. If you are an expert user and did so for research purposes, this is fine. If not, you might be doing something wrong: feel free to create an issue on Github.
#   self._check_proposal(proposal)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 20 epochs.
#         -------------------------
#         ||||| ROUND 2 STATS |||||:
#         -------------------------
#         Epochs trained: 20
#         Best validation performance: 0.0068
#         -------------------------
#
# Round 3
# Generating training examples.
# Drawing 1844 posterior samples:   0%|          | 0/1844 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_0_3.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1060.41it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_3_3.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1259.20it/s]
#   0%|          | 0/256 [00:00<?, ?it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_7_3.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 788.87it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_4_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1792.43it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_5_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1539.59it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_1_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1762.08it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_2_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1826.41it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_6_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1769.07it/s]
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 32 epochs.
#         -------------------------
#         ||||| ROUND 3 STATS |||||:
#         -------------------------
#         Epochs trained: 32
#         Best validation performance: 0.0040
#         -------------------------
#
# Round 4
# Generating training examples.
# Drawing 1844 posterior samples:   0%|          | 0/1844 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_0_4.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 853.95it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_6_4.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1041.54it/s]
#  27%|██▋       | 68/256 [00:00<00:00, 678.54it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_7_4.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 649.64it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_5_4.log
# Reading ARCiS output...
#   0%|          | 0/256 [00:00<?, ?it/s]16.55it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_3_4.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 781.55it/s]
# 100%|██████████| 256/256 [00:00<00:00, 743.10it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_4_4.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1377.72it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_2_4.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1410.69it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_1_4.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1455.59it/s]
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 11 epochs.
#         -------------------------
#         ||||| ROUND 4 STATS |||||:
#         -------------------------
#         Epochs trained: 11
#         Best validation performance: 0.0089
#         -------------------------
#
# Round 5
# Generating training examples.
# Drawing 1844 posterior samples:   0%|          | 0/1844 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_0_5.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 928.78it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_3_5.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1192.03it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_7_5.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 1360.22it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_5_5.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_1_5.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 256/256 [00:00<00:00, 1370.31it/s]
#   0%|          | 0/256 [00:00<?, ?it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_6_5.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_4_5.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 796.77it/s]
# 100%|██████████| 256/256 [00:00<00:00, 938.76it/s]
# 100%|██████████| 256/256 [00:00<00:00, 870.15it/s]
# Removing files...
# Removing files...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_codex_version_3/arcis_run_2_5.log
# Reading ARCiS output...
# 100%|██████████| 256/256 [00:00<00:00, 819.33it/s]
# Removing files...
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 16 epochs.
#         -------------------------
#         ||||| ROUND 5 STATS |||||:
#         -------------------------
#         Epochs trained: 16
#         Best validation performance: 0.0045
#         -------------------------

# %% [markdown]
# #### Plot loss

# %%
# %matplotlib inline
plt.plot(R.inference._summary['best_validation_loss'], marker='o')
plt.xlabel('Round')
plt.ylabel('Validation Loss')
plt.show()

# %% [markdown]
# #### Plot posterior

# %%
full = []
for key in R.parameters:
    ranges_m = R.parameters[key]['min']
    ranges_p = R.parameters[key]['max']
    full.append((ranges_m, ranges_p))

# %%
CORNER_KWARGS=dict(
    smooth=0.6,
    plot_density=True,
    hist_bin_factor=1,
    plot_contours=True,
    show_titles=True,
    color='mediumpurple',
    range=full,
)
fig=R.plot_corner(-1,**CORNER_KWARGS)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## Posterior diagnostics

# %% [markdown]
# ### Posterior predictive check

# %%
# %matplotlib inline
xs = R.post_x
# Xs=np.concatenate(list(xs.values()), axis=1)

plt.figure(figsize=(40,10))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='r', lw=1, zorder=0)
for i in trange(len(xs[0])):
    for key in R.obs.keys():
        plt.plot(R.obs[key][:,0], xs[key][i], c='b', alpha=0.01, zorder=1)
plt.xlim(0.5,2)
plt.ylim(-1e-6,2e-5)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.show()
# Out:
# 100%|██████████| 512/512 [00:02<00:00, 243.17it/s]

# %%
helpers.find_best_fit(R.obs, xs)
# Out:
# {0: (np.int64(123), np.float64(138.79225586056472)),
#  1: (np.int64(260), np.float64(36.49275215503635)),
#  2: (np.int64(508), np.float64(309.93647292400937)),
#  3: (np.int64(227), np.float64(186.88681831867692))}

# %%
plt.figure(figsize=(24,8))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='r', lw=1, zorder=0)
    plt.plot(R.obs[key][:,0], xs[key][7], c='k', alpha=1, zorder=1)
plt.xlim(0.9,2)
plt.ylim(-1e-6,2e-5)
# Out:
# (-1e-06, 2e-05)
