# %%
from floppity import Retrieval, helpers
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', size=16)
import torch
from corner import corner
import cloudpickle as pickle
from tqdm import trange
from floppity.simulators import read_ARCiS_input, ARCiS

# %% [markdown]
# #### Set-up retrieval

# %% [markdown]
# Let's first define the ARCiS input file we will be using, and read the
# observations and parameters to be fit from it. We will also pass the input file and the output directory to the ARCiS simulator (a python wrapper that calls your ARCiS installation).

# %%
arcis_input='/Users/floppityflappity/Work/WISE1828/input_j1828_chem.dat'
pars, obs_list = read_ARCiS_input(arcis_input)

ARCiS_kwargs= dict(
    input_file = arcis_input,
    output_dir = '/Users/floppityflappity/Work/WISE1828/test_pca_20',
)

# %% [markdown]
# Let's now define the training and flow hyperparameters.

# %%
training_kwargs= dict(
    stop_after_epochs = 20,
    num_atoms = 10,
    learning_rate=1e-3,
    force_first_round_loss=True,
    use_combined_loss=True
)

flow_kwargs=dict(
    flow='nsf',
    bins=4,
    transforms=8,
    blocks=2,
    hidden=32,
    dropout=0.01,
    # max_num_epochs=500,
)

# %% [markdown]
# Now let's create our retrieval object and load the observations and priors into it.

# %%
R = Retrieval(ARCiS, do_pca=True)
R.parameters=pars
R.get_obs(obs_list)

# %% [markdown]
# Additional parameters can be added as shown below.
# The post_process tag means that they're not passed onto the simulator but the spectra are modified a posteriori using one of the functions in postprocessing.py

# %%
# R.add_parameter('RV', -40,-30, post_process=True)
# R.add_parameter('vrot', 50,70, post_process=True)

# %% [markdown]
# #### Run retrieval

# %%
R.run(flow_kwargs=flow_kwargs, training_kwargs=training_kwargs, simulator_kwargs=ARCiS_kwargs,
      resume=False, n_threads=8,  n_rounds=5, n_samples=512, n_pca=20, save_data=True, 
      reuse_prior='/Users/floppityflappity/Work/WISE1828/test_pca_10/data_0.pkl',
      output_dir=ARCiS_kwargs['output_dir']
      )
# Out:
# Starting training...
# Round 1
# Reusing prior data from /Users/floppityflappity/Work/WISE1828/test_pca_10/data_0.pkl
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
#  Neural network successfully converged after 88 epochs.
#         -------------------------
#         ||||| ROUND 1 STATS |||||:
#         -------------------------
#         Epochs trained: 88
#         Best validation performance: 11.3114
#         -------------------------
#
# Round 2
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_1_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 917.10it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_4_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 884.35it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_7_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1076.32it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_5_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1094.52it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_3_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1118.80it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_0_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1091.82it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_2_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1116.23it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_6_1.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1115.23it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 112 epochs.
#         -------------------------
#         ||||| ROUND 2 STATS |||||:
#         -------------------------
#         Epochs trained: 112
#         Best validation performance: 3.6360
#         -------------------------
#
# Round 3
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_2_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 594.62it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_3_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1067.86it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_7_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 920.89it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_4_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 894.19it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_1_2.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_0_2.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_5_2.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 882.32it/s]
# 100%|██████████| 64/64 [00:00<00:00, 831.14it/s]
# 100%|██████████| 64/64 [00:00<00:00, 438.22it/s]
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_6_2.log
# Reading ARCiS output...
# 100%|██████████| 64/64 [00:00<00:00, 977.17it/s]
# Removing files...
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 36 epochs.
#         -------------------------
#         ||||| ROUND 3 STATS |||||:
#         -------------------------
#         Epochs trained: 36
#         Best validation performance: -1.4094
#         -------------------------
#
# Round 4
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_3_3.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_4_3.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_5_3.log
# Reading ARCiS output...
# Removing files...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 958.63it/s]
# 100%|██████████| 64/64 [00:00<00:00, 932.81it/s]
# 100%|██████████| 64/64 [00:00<00:00, 979.06it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_7_3.log
# Reading ARCiS output...
# Removing files...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_2_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1098.07it/s]
# 100%|██████████| 64/64 [00:00<00:00, 864.40it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_6_3.log
# Reading ARCiS output...
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_1_3.log
# Reading ARCiS output...
# Removing files...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1057.82it/s]
# 100%|██████████| 64/64 [00:00<00:00, 1050.87it/s]
# ARCiS finished successfully. Output logged to: /Users/floppityflappity/Work/WISE1828/test_pca_20/arcis_run_0_3.log
# Reading ARCiS output...
# Removing files...
# 100%|██████████| 64/64 [00:00<00:00, 1094.28it/s]
# Saving data...
# /opt/anaconda3/envs/floppity_dev/lib/python3.12/site-packages/cloudpickle/cloudpickle.py:1303: UserWarning: When the inference object is pickled, the behaviour of the loaded object changes in the following two ways: 1) `.train(..., retrain_from_scratch=True)` is not supported. 2) When the loaded object calls the `.train()` method, it generates a new tensorboard summary writer (instead of appending to the current one).
#   return super().dump(obj)
# Using SNPE-C with atomic loss
#  Neural network successfully converged after 52 epochs.
#         -------------------------
#         ||||| ROUND 4 STATS |||||:
#         -------------------------
#         Epochs trained: 52
#         Best validation performance: -3.0275
#         -------------------------
#
# Round 5
# Generating training examples.
# Drawing 512 posterior samples:   0%|          | 0/512 [00:00<?, ?it/s]
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# Warning: Found "makeai=.false." — changing to "makeai=.true."
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 R.run(flow_kwargs=flow_kwargs, training_kwargs=training_kwargs, simulator_kwargs=ARCiS_kwargs,
#       2       resume=False, n_threads=8,  n_rounds=5, n_samples=512, n_pca=20, save_data=True,
#       3       reuse_prior='/Users/floppityflappity/Work/WISE1828/test_pca_10/data_0.pkl',
#       4       output_dir=ARCiS_kwargs['output_dir']
#       5       )
#
# File ~/Work/FlopPITy_v2/FlopPITy/src/floppity/flappity.py:526, in Retrieval.run(self, n_threads, n_samples, n_samples_init, resume, n_rounds, n_aug, flow_kwargs, training_kwargs, simulator_kwargs, output_dir, save_data, sample_prior_method, reuse_prior, IS, n_pca)
#     523 for r in range(r0, n_rounds):
#     524     print(f"Round {r+1}")
# --> 526     theta_tensor, x_tensor = self.generate_training_data(
#     527         proposal=proposal,
#     528         r=r,
#     529         n_samples=n_samples,
#     530         n_samples_init=n_samples_init,
#     531         sample_prior_method=sample_prior_method,
#     532         n_threads=n_threads,
#     533         simulator_kwargs=simulator_kwargs,
#     534         n_aug=n_aug,
#     535         reuse_prior=reuse_prior if r == 0 else None
#     536     )
#     538     # this is a quick hack:
#     539     if self.simulator==simulators.ARCiS_multiple:
#
# File ~/Work/FlopPITy_v2/FlopPITy/src/floppity/flappity.py:460, in Retrieval.generate_training_data(self, proposal, r, n_samples, n_samples_init, sample_prior_method, n_threads, simulator_kwargs, n_aug, reuse_prior)
#     458         xs = self.simulator(self.obs, self.thetas[:, :self.sim_pars], **simulator_kwargs)
#     459     else:
# --> 460         xs = self.psimulator(self.obs, self.thetas[:, :self.sim_pars], **simulator_kwargs)
#     462     self.get_x(xs)
#     464 # Postprocessing
#
# File ~/Work/FlopPITy_v2/FlopPITy/src/floppity/flappity.py:771, in Retrieval.psimulator(self, obs, parameters, **kwargs)
#     768 mp_context = "spawn"
#     770 with mp.get_context(mp_context).Pool(processes=self.n_threads) as pool:
# --> 771     spectra_parts = pool.map(_run_single_chunk, args)
#     773 # Combine results across threads
#     774 combined_spectra = {k: [] for k in obs}
#
# File /opt/anaconda3/envs/floppity_dev/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/anaconda3/envs/floppity_dev/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/anaconda3/envs/floppity_dev/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/anaconda3/envs/floppity_dev/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/anaconda3/envs/floppity_dev/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Plot loss

# %%
# %matplotlib inline
plt.plot(R.inference._summary['best_validation_loss'], marker='o')
plt.xlabel('Round')
plt.ylabel('Validation Loss')
plt.show()

# %% [markdown]
# #### Plot posterior

# %% [markdown]
# This is just to get all the parameter names and priors for the figure labels

# %%
full = []
for key in R.parameters:
    ranges_m = R.parameters[key]['min']
    ranges_p = R.parameters[key]['max']
    full.append((ranges_m, ranges_p))

# %%
CORNER_KWARGS=dict(
    smooth=0.6,
    plot_density=True,
    hist_bin_factor=1,
    plot_contours=True,
    show_titles=True,
    
    range=full,
)
fig=R.plot_corner(-1, color='mediumpurple',**CORNER_KWARGS)

# fig1=R.plot_corner(-2, fig=fig, color='orchid', **CORNER_KWARGS)
# fig2=R.plot_corner(-3, fig=fig, color='pink', **CORNER_KWARGS)
# Out:
# Drawing 1000 posterior samples:   0%|          | 0/1000 [00:00<?, ?it/s]
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# ## Posterior diagnostics

# %% [markdown]
# ### Posterior predictive check

# %%
x_tensor = R.x_transformer.transform(R.pca.transform(R.noisy_x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_tensor = R.x_transformer.transform(R.pca.transform(R.noisy_x))
#
# AttributeError: 'Retrieval' object has no attribute 'pca'

# %%
plt.plot(R.default_obs_norm[0],zorder=1)
for i in range(512):
    plt.plot(x_tensor[i], color='lightgray', alpha=0.05)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 plt.plot(R.default_obs_norm[0],zorder=1)
#       2 for i in range(512):
# ----> 3     plt.plot(x_tensor[i], color='lightgray', alpha=0.05)
#
# NameError: name 'x_tensor' is not defined

# %%
# %matplotlib inline
xs = R.post_x
# Xs=np.concatenate(list(xs.values()), axis=1)

plt.figure(figsize=(40,10))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='r', lw=1, zorder=0)
for i in trange(len(xs['obs1'])):
    for key in R.obs.keys():
        plt.plot(R.obs[key][:,0], xs[key][i], c='b', alpha=0.01, zorder=1)
# plt.xlim(0.5,2)
# plt.ylim(-1e-6,2e-5)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.show()
# Out:
# 100%|██████████| 512/512 [00:00<00:00, 1041.69it/s]

# %% [markdown]
# ### Check best fitting model from the training set

# %%
bf_idx, bf_chi=helpers.find_best_fit(R.obs, xs)

# %%
plt.figure(figsize=(24,8))
for key in R.obs.keys():
    plt.errorbar(x=R.obs[key][:,0], y=R.obs[key][:,1], yerr=R.obs[key][:,2], c='k', lw=1, zorder=0)
    plt.plot(R.obs[key][:,0], xs[key][bf_idx], c='r', alpha=1, zorder=1)
# plt.xlim(0.9,2)
# plt.ylim(-1e-6,2e-5)
